# %% [markdown]
# # For Plotting NIS Radar and NIS Laser

# %%
# import sys
# print(sys.path)

# %%
# sys.executable

# %%
# !jupyter-troubleshoot

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline


data_r = pd.read_csv('./NIS_RADAR.txt', sep=",")
data_r.head()
plt.figure(figsize=(10,6))
plt.plot(data_r['Radar NIS'], label='NIS Radar')
plt.plot([0,len(data_r['Radar NIS'])],[7.815,7.815],'r--',lw=2, label='Chi square = 7.815 for 3 DOF')
plt.xlabel('t')
plt.ylabel('NIS')
plt.title('NIS Radar')
plt.legend()

# %%
data_l = pd.read_csv('./NIS_LIDAR.txt', sep=",")
data_l.head()
plt.figure(figsize=(10,6))
plt.plot(data_l['Lidar NIS'], label='NIS Lidar Data')
plt.plot([0,len(data_l['Lidar NIS'])],[5.991,5.991],'r--',lw=2, label='Chi square = 5.991 for 2 DOF')
plt.xlabel('x')
plt.ylabel('y')
plt.title('NIS Lidar vs Steps')
plt.legend()
